# %%
import json, matplotlib.pyplot as plt, pandas as pd, numpy as np
# %matplotlib inline

# %%
json.load((open('/Users/lacivert/1mo1yr10yr30yr.json')))
# Out:
# [{'1 mo': 0.52, '1 yr': 0.89, '10 yr': 2.45, '30 yr': 3.04},
#  {'1 mo': 0.49, '1 yr': 0.87, '10 yr': 2.46, '30 yr': 3.05},
#  {'1 mo': 0.51, '1 yr': 0.83, '10 yr': 2.37, '30 yr': 2.96},
#  {'1 mo': 0.5, '1 yr': 0.85, '10 yr': 2.42, '30 yr': 3},
#  {'1 mo': 0.5, '1 yr': 0.82, '10 yr': 2.38, '30 yr': 2.97},
#  {'1 mo': 0.51, '1 yr': 0.82, '10 yr': 2.38, '30 yr': 2.97},
#  {'1 mo': 0.51, '1 yr': 0.82, '10 yr': 2.38, '30 yr': 2.96},
#  {'1 mo': 0.52, '1 yr': 0.81, '10 yr': 2.36, '30 yr': 3.01},
#  {'1 mo': 0.52, '1 yr': 0.82, '10 yr': 2.4, '30 yr': 2.99},
#  {'1 mo': 0.52, '1 yr': 0.8, '10 yr': 2.33, '30 yr': 2.93},
#  {'1 mo': 0.48, '1 yr': 0.82, '10 yr': 2.42, '30 yr': 3},
#  {'1 mo': 0.47, '1 yr': 0.83, '10 yr': 2.47, '30 yr': 3.04},
#  {'1 mo': 0.46, '1 yr': 0.82, '10 yr': 2.48, '30 yr': 3.05},
#  {'1 mo': 0.46, '1 yr': 0.79, '10 yr': 2.41, '30 yr': 2.99},
#  {'1 mo': 0.5, '1 yr': 0.81, '10 yr': 2.47, '30 yr': 3.05},
#  {'1 mo': 0.48, '1 yr': 0.82, '10 yr': 2.53, '30 yr': 3.1},
# ...

# %%
sample_json_df = pd.read_json('/Users/lacivert/1mo1yr10yr30yr.json')

# %%
plt.plot(sample_json_df,color='green'), 
plt.ylabel('1 Mo, 1 Yr, 10 Yr, 30 Yr  U.S. Treasury Rates',color='crimson'), 
plt.xlabel('Market Open Days',color='olive'), 
plt.title('2017', color='blue')
# Out:
# Text(0.5,1,'2017')

# %%
sample_json_df.describe()
# Out:
#              1 mo        1 yr       10 yr       30 yr
# count  250.000000  250.000000  250.000000  250.000000
# mean     0.851000    1.202880    2.329480    2.894040
# std      0.221686    0.252874    0.108628    0.116943
# min      0.390000    0.790000    2.050000    2.660000
# 25%      0.720000    1.030000    2.250000    2.800000
# 50%      0.915000    1.220000    2.340000    2.880000
# 75%      1.000000    1.317500    2.400000    2.990000
# max      1.300000    1.760000    2.620000    3.200000

# %%
#assign DataFrame
df = pd.DataFrame(sample_json_df)

# %%
#list column names
list(df.columns.values)
# Out:
# ['1 mo', '1 yr', '10 yr', '30 yr']

# %%
df.boxplot()
