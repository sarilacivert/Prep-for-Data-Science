# %%
import json, matplotlib.pyplot as plt, pandas as pd, numpy as np

# %%
json.load((open('/Users/lacivert/datasciproposal/1mo.json')))
# Out:
# [{'1 mo': 0.52},
#  {'1 mo': 0.49},
#  {'1 mo': 0.51},
#  {'1 mo': 0.5},
#  {'1 mo': 0.5},
#  {'1 mo': 0.51},
#  {'1 mo': 0.51},
#  {'1 mo': 0.52},
#  {'1 mo': 0.52},
#  {'1 mo': 0.52},
#  {'1 mo': 0.48},
#  {'1 mo': 0.47},
#  {'1 mo': 0.46},
#  {'1 mo': 0.46},
#  {'1 mo': 0.5},
#  {'1 mo': 0.48},
#  {'1 mo': 0.49},
#  {'1 mo': 0.49},
#  {'1 mo': 0.49},
#  {'1 mo': 0.5},
#  {'1 mo': 0.5},
#  {'1 mo': 0.5},
#  {'1 mo': 0.49},
#  {'1 mo': 0.48},
#  {'1 mo': 0.51},
#  {'1 mo': 0.52},
#  {'1 mo': 0.51},
#  {'1 mo': 0.51},
#  {'1 mo': 0.5},
#  {'1 mo': 0.51},
#  {'1 mo': 0.53},
#  {'1 mo': 0.51},
#  {'1 mo': 0.5},
#  {'1 mo': 0.49},
#  {'1 mo': 0.47},
#  {'1 mo': 0.39},
#  {'1 mo': 0.4},
#  {'1 mo': 0.44},
#  {'1 mo': 0.4},
#  {'1 mo': 0.46},
#  {'1 mo': 0.52},
#  {'1 mo': 0.56},
#  {'1 mo': 0.56},
#  {'1 mo': 0.55},
#  {'1 mo': 0.54},
#  {'1 mo': 0.5},
#  {'1 mo': 0.6},
#  {'1 mo': 0.69},
#  {'1 mo': 0.77},
#  {'1 mo': 0.71},
#  {'1 mo': 0.68},
#  {'1 mo': 0.71},
#  {'1 mo': 0.7},
# ...

# %%
sample_json_df = pd.read_json((open('/Users/lacivert/datasciproposal/1mo.json')))

# %%
plt.plot(sample_json_df,color='green'), 
plt.ylabel('1 Month U.S. Treasury Rates',color='crimson'), 
plt.xlabel('Market Open Days',color='olive'), 
plt.title('2017', color='blue')
# Out:
# Text(0.5,1,'2017')

# %%
sample_json_df.describe()
# Out:
#              1 mo
# count  250.000000
# mean     0.851000
# std      0.221686
# min      0.390000
# 25%      0.720000
# 50%      0.915000
# 75%      1.000000
# max      1.300000

# %%
print (((np.var(sample_json_df))**0.5)==(np.std(sample_json_df)))
# Out:
# 1 mo    True
# dtype: bool
